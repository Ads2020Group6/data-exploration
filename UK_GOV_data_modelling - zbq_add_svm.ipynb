# %% [markdown]
# # Modelling gender pay gap data
#
# Aim is to get insights from different models and compare. This would help direct future data collection, too.
#
# Getting insights is probably more important than predictions for this dataset since it is unclear what may be the cause of gender pay gap.
#
# ### Some assumptions:
#
# - From data exploration and through gender pay gap reports we see the difference in number of women and men in upper quartile and lower quartile to be a potential factor.
# - We believe the company size could also play a role because ...
# - Gender pay gap can be more obvious in some industries than others

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'data/gender-pay-gap-uk-gov/2018.csv.gz'
data = pd.read_csv(url, compression='gzip')
data.head()
# Out:
#                            EmployerName  \
# 0       "Bryanston School",Incorporated
# 1  "RED BAND" CHEMICAL COMPANY, LIMITED
# 2                           118 LIMITED
# 3                     123 EMPLOYEES LTD
# 4                            1509 GROUP
#
#                                              Address CompanyNumber  \
# 0  Bryanston House,\r\nBlandford,\r\nDorset,\r\nD...      00226143
# 1  19 Smith's Place,\r\nLeith Walk,\r\nEdinburgh,...      SC016876
# 2  3 Alexandra Gate Ffordd Pengam,\r\nGround Floo...      03951948
# 3  34 Roundhay Road,\r\nLeeds,\r\nEngland,\r\nLS7...      10530651
# 4  Royal Grammar School,\r\nHigh Street,\r\nGuild...      04104101
#
#           SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 0            85310                   19.6                     32.5
# 1            47730                    7.7                     -4.2
# 2            61900                    7.7                     12.7
# 3            78300                   30.0                     29.0
# 4  85200,\r\n85310                   13.4                     12.7
#
#    DiffMeanBonusPercent  DiffMedianBonusPercent  MaleBonusPercent  \
# 0                   NaN                     NaN               0.0
# 1                  23.7                   -75.2              22.2
# 2                  11.3                    10.9              67.0
# 3                 -10.0                    69.0              46.0
# 4                   0.0                     0.0               0.0
#
#    FemaleBonusPercent  ...  FemaleUpperMiddleQuartile  MaleTopQuartile  \
# 0                 0.0  ...                       55.1             53.3
# 1                82.0  ...                       88.4             20.3
# 2                52.0  ...                       50.0             56.0
# 3                74.0  ...                       83.0             25.0
# 4                 0.0  ...                       51.6             61.3
#
#    FemaleTopQuartile                    CompanyLinkToGPGInfo  \
# 0               46.7  https://www.bryanston.co.uk/employment
# 1               79.7                                     NaN
# 2               44.0                                     NaN
# 3               75.0                                     NaN
# 4               38.7         https://www.rgs-guildford.co.uk
#
#                             ResponsiblePerson  EmployerSize  \
# 0  Michael McGovern (Chief Operating Officer)    500 to 999
# 1             Philip Galt (Managing Director)    250 to 499
# 2                        Michael Graham (CEO)  1000 to 4999
# 3          Chloe Lines (Financial Controller)    250 to 499
# 4                      Kate Perceval (Bursar)    250 to 499
#
#                             CurrentName  SubmittedAfterTheDeadline  \
# 0         BRYANSTON SCHOOL INCORPORATED                      False
# 1  "RED BAND" CHEMICAL COMPANY, LIMITED                      False
# 2                           118 LIMITED                      False
# 3                     123 EMPLOYEES LTD                      False
# 4                            1509 GROUP                      False
#
#                DueDate        DateSubmitted
# 0  05/04/2019 00:00:00  03/04/2019 13:43:34
# 1  05/04/2019 00:00:00  01/04/2019 12:37:21
# 2  05/04/2019 00:00:00  06/03/2019 13:26:24
# 3  05/04/2019 00:00:00  03/04/2019 15:43:17
# 4  05/04/2019 00:00:00  18/03/2019 14:03:16
#
# [5 rows x 25 columns]

# %%
data.shape
# Out:
# (10817, 25)

# %%
#Columns that have a single value for all rows do not contain any information for modeling.

print(data.nunique())
# Out:
# EmployerName                 10817
# Address                       9313
# CompanyNumber                 9478
# SicCodes                      2004
# DiffMeanHourlyPercent          851
# DiffMedianHourlyPercent        891
# DiffMeanBonusPercent          1712
# DiffMedianBonusPercent        1761
# MaleBonusPercent               978
# FemaleBonusPercent             974
# MaleLowerQuartile              977
# FemaleLowerQuartile            977
# MaleLowerMiddleQuartile        982
# FemaleLowerMiddleQuartile      982
# MaleUpperMiddleQuartile        976
# FemaleUpperMiddleQuartile      976
# MaleTopQuartile                946
# FemaleTopQuartile              946
# CompanyLinkToGPGInfo          6244
# ResponsiblePerson             7509
# EmployerSize                     7
# CurrentName                  10816
# SubmittedAfterTheDeadline        2
# DueDate                          2
# DateSubmitted                10695
# dtype: int64

# %%
# drop columns with 2 unique values and the ones that make no difference like ResponsiblePerson
del_cols = ["ResponsiblePerson","SubmittedAfterTheDeadline","DueDate","DateSubmitted"]
data.drop(del_cols, axis=1, inplace=True)
data.shape
# Out:
# (10817, 21)

# %%
# calculate duplicates
dups = data.duplicated()
# report if there are any duplicates
print(dups.any())
# Out:
# False

# %% [markdown]
# No duplicate rows!
#
# if there were, drop with: data.drop_duplicates(inplace=True)

# %%
data.describe()
# Out:
#        DiffMeanHourlyPercent  DiffMedianHourlyPercent  DiffMeanBonusPercent  \
# count           10817.000000             10817.000000           9068.000000
# mean               14.182555                11.882851             18.401390
# std                14.243119                15.512442            219.025483
# min               -98.700000               -92.300000         -13934.000000
# 25%                 4.900000                 0.900000              0.000000
# 50%                13.100000                 9.500000             32.050000
# 75%                22.400000                21.000000             56.600000
# max               100.000000               100.000000            134.200000
#
#        DiffMedianBonusPercent  MaleBonusPercent  FemaleBonusPercent  \
# count             9068.000000      10817.000000        10817.000000
# mean                -1.033855         35.706749           34.378941
# std                295.383196         36.675086           36.375891
# min             -14490.800000          0.000000            0.000000
# 25%                  0.000000          0.700000            0.300000
# 50%                 15.550000         19.200000           17.100000
# 75%                 43.000000         75.100000           71.900000
# max               4000.000000        100.000000          100.000000
#
#        MaleLowerQuartile  FemaleLowerQuartile  MaleLowerMiddleQuartile  \
# count       10817.000000         10817.000000              10817.00000
# mean           46.115568            53.884432                 50.17099
# std            24.113495            24.113495                 26.19021
# min             0.000000             0.000000                  0.00000
# 25%            27.000000            35.500000                 29.00000
# 50%            44.600000            55.400000                 48.00000
# 75%            64.500000            73.000000                 72.00000
# max           100.000000           100.000000                100.00000
#
#        FemaleLowerMiddleQuartile  MaleUpperMiddleQuartile  \
# count                10817.00000             10817.000000
# mean                    49.82901                54.384718
# std                     26.19021                26.318576
# min                      0.00000                 0.000000
# 25%                     28.00000                33.000000
# 50%                     52.00000                53.000000
# 75%                     71.00000                78.000000
# max                    100.00000               100.000000
#
#        FemaleUpperMiddleQuartile  MaleTopQuartile  FemaleTopQuartile
# count               10817.000000     10817.000000       10817.000000
# mean                   45.615282        60.253000          39.747000
# std                    26.318576        24.487098          24.487098
# min                     0.000000         0.000000           0.000000
# 25%                    22.000000        41.000000          18.000000
# 50%                    47.000000        62.000000          38.000000
# 75%                    67.000000        82.000000          59.000000
# max                   100.000000       100.000000         100.000000

# %% [markdown]
# From count we see the DiffMeanBonusPercent and DiffMedianBonusPercent have missing values.
#
# The max and min values are also crazy.

# %%
#borrowed from Lean's notebook

# Mean because the measurement is mean
mean_bonus_percent = data['DiffMeanBonusPercent'].mean()
data['DiffMeanBonusPercent'] = data['DiffMeanBonusPercent'].fillna(mean_bonus_percent)

# Median because the measurement is median
median_bonus_percent = data['DiffMedianBonusPercent'].median()
data['DiffMedianBonusPercent'] = data['DiffMedianBonusPercent'].fillna(median_bonus_percent)

# keeping crazy data because bonuses can be crazy 16-04
# clean up - dropping all with values bigger than 100
# data = data[(data.DiffMeanBonusPercent>-100) & 
#      (data.DiffMeanBonusPercent<100) &
#      (data.DiffMedianBonusPercent>-100) &
#      (data.DiffMedianBonusPercent<100)]

# %%
data.describe()
# Out:
#        DiffMeanHourlyPercent  DiffMedianHourlyPercent  DiffMeanBonusPercent  \
# count           10817.000000             10817.000000          10817.000000
# mean               14.182555                11.882851             18.401390
# std                14.243119                15.512442            200.536355
# min               -98.700000               -92.300000         -13934.000000
# 25%                 4.900000                 0.900000              7.000000
# 50%                13.100000                 9.500000             21.800000
# 75%                22.400000                21.000000             51.600000
# max               100.000000               100.000000            134.200000
#
#        DiffMedianBonusPercent  MaleBonusPercent  FemaleBonusPercent  \
# count            10817.000000      10817.000000        10817.000000
# mean                 1.647587         35.706749           34.378941
# std                270.517216         36.675086           36.375891
# min             -14490.800000          0.000000            0.000000
# 25%                  0.000000          0.700000            0.300000
# 50%                 15.550000         19.200000           17.100000
# 75%                 37.500000         75.100000           71.900000
# max               4000.000000        100.000000          100.000000
#
#        MaleLowerQuartile  FemaleLowerQuartile  MaleLowerMiddleQuartile  \
# count       10817.000000         10817.000000              10817.00000
# mean           46.115568            53.884432                 50.17099
# std            24.113495            24.113495                 26.19021
# min             0.000000             0.000000                  0.00000
# 25%            27.000000            35.500000                 29.00000
# 50%            44.600000            55.400000                 48.00000
# 75%            64.500000            73.000000                 72.00000
# max           100.000000           100.000000                100.00000
#
#        FemaleLowerMiddleQuartile  MaleUpperMiddleQuartile  \
# count                10817.00000             10817.000000
# mean                    49.82901                54.384718
# std                     26.19021                26.318576
# min                      0.00000                 0.000000
# 25%                     28.00000                33.000000
# 50%                     52.00000                53.000000
# 75%                     71.00000                78.000000
# max                    100.00000               100.000000
#
#        FemaleUpperMiddleQuartile  MaleTopQuartile  FemaleTopQuartile
# count               10817.000000     10817.000000       10817.000000
# mean                   45.615282        60.253000          39.747000
# std                    26.318576        24.487098          24.487098
# min                     0.000000         0.000000           0.000000
# 25%                    22.000000        41.000000          18.000000
# 50%                    47.000000        62.000000          38.000000
# 75%                    67.000000        82.000000          59.000000
# max                   100.000000       100.000000         100.000000

# %%
new_data = data[['SicCodes','DiffMeanHourlyPercent','DiffMedianHourlyPercent','DiffMeanBonusPercent','DiffMedianBonusPercent',
                 'MaleBonusPercent','FemaleBonusPercent','MaleLowerQuartile','FemaleLowerQuartile',
       'MaleLowerMiddleQuartile', 'FemaleLowerMiddleQuartile',
       'MaleUpperMiddleQuartile', 'FemaleUpperMiddleQuartile',
       'MaleTopQuartile', 'FemaleTopQuartile','EmployerSize']]
new_data.dropna(axis=0, inplace = True) #droping missing values everywhere
print(new_data.shape)
# Out:
# (10317, 16)
# C:\Users\zbqv\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#picked up on the internet
def sic_desc(df,sic):
    
    df = df[~df.SicCodes.isna()]
    
    df['SicCodes'] = df.apply(lambda row: row.SicCodes.replace('\n','')\
                                                      .replace('\r','')\
                                                      .split(','), axis=1)
    df = df.explode('SicCodes')
    df['SicCodes'] = pd.to_numeric(df.SicCodes)
    
    return df.merge(sic, how='left', left_on='SicCodes', 
                    right_on='SIC Code')

# %%
siccodeUrl = "data/siccodes/SIC07_CH_condensed_list_en.csv"
siccode = pd.read_csv(siccodeUrl)
siccode.head()
# Out:
#    SIC Code                                        Description
# 0      1110  Growing of cereals (except rice), leguminous c...
# 1      1120                                    Growing of rice
# 2      1130  Growing of vegetables and melons, roots and tu...
# 3      1140                              Growing of sugar cane
# 4      1150                                 Growing of tobacco

# %%
new_data = sic_desc(new_data,siccode)

# %%
# https://www.datacamp.com/community/tutorials/categorical-data
#used label encoding but would one hot encoding be better
new_data['EmployerSize'] = new_data['EmployerSize'].astype('category')
print(new_data['EmployerSize'].unique())
new_data['EmployerSize'] = new_data['EmployerSize'].cat.codes
print(new_data['EmployerSize'].unique())
# Out:
# [500 to 999, 250 to 499, 1000 to 4999, 5000 to 19,999, Less than 250, 20,000 or more, Not Provided]
# Categories (7, object): [500 to 999, 250 to 499, 1000 to 4999, 5000 to 19,999, Less than 250, 20,000 or more, Not Provided]
# [3 2 0 4 5 1 6]

# %%
new_data.describe()
# Out:
#            SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# count  15747.000000           15747.000000             15747.000000
# mean   56617.536737              14.482911                12.874852
# std    30098.741027              13.745030                15.786387
# min        1.000000             -98.700000               -92.300000
# 25%    41100.000000               5.400000                 1.500000
# 50%    62090.000000              13.800000                10.600000
# 75%    85100.000000              22.800000                22.350000
# max    99999.000000             100.000000               100.000000
#
#        DiffMeanBonusPercent  DiffMedianBonusPercent  MaleBonusPercent  \
# count          15747.000000            15747.000000      15747.000000
# mean              19.058160                3.047400         32.443729
# std              170.546777              240.901057         36.196676
# min           -13934.000000           -14490.800000          0.000000
# 25%                6.300000                0.000000          0.000000
# 50%               18.401390               15.550000         13.000000
# 75%               49.500000               35.800000         70.000000
# max              134.200000             4000.000000        100.000000
#
#        FemaleBonusPercent  MaleLowerQuartile  FemaleLowerQuartile  \
# count        15747.000000       15747.000000         15747.000000
# mean            30.977094          44.344739            55.655261
# std             35.681374          24.619922            24.619922
# min              0.000000           0.000000             0.000000
# 25%              0.000000          24.000000            36.400000
# 50%             11.000000          42.000000            58.000000
# 75%             65.100000          63.600000            76.000000
# max            100.000000         100.000000           100.000000
#
#        MaleLowerMiddleQuartile  FemaleLowerMiddleQuartile  \
# count             15747.000000               15747.000000
# mean                 48.329803                  51.670197
# std                  26.535843                  26.535843
# min                   0.000000                   0.000000
# 25%                  26.500000                  29.000000
# 50%                  45.000000                  55.000000
# 75%                  71.000000                  73.500000
# max                 100.000000                 100.000000
#
#        MaleUpperMiddleQuartile  FemaleUpperMiddleQuartile  MaleTopQuartile  \
# count             15747.000000               15747.000000     15747.000000
# mean                 52.662386                  47.337614        58.509208
# std                  26.737917                  26.737917        24.979916
# min                   0.000000                   0.000000         0.000000
# 25%                  30.200000                  22.500000        38.000000
# 50%                  50.000000                  50.000000        59.000000
# 75%                  77.500000                  69.800000        81.600000
# max                 100.000000                 100.000000       100.000000
#
#        FemaleTopQuartile  EmployerSize      SIC Code
# count       15747.000000  15747.000000  13913.000000
# mean           41.490792      1.987236  64080.681162
# std            24.979916      1.278317  23389.997710
# min             0.000000      0.000000   1110.000000
# 25%            18.400000      2.000000  46730.000000
# 50%            41.000000      2.000000  70100.000000
# 75%            62.000000      3.000000  85200.000000
# max           100.000000      6.000000  99999.000000

# %%
new_data.dropna(axis=0) #dropping ones without siccode
# Out:
#        SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 0         85310                   19.6                     32.5
# 1         47730                    7.7                     -4.2
# 2         61900                    7.7                     12.7
# 3         78300                   30.0                     29.0
# 4         85200                   13.4                     12.7
# ...         ...                    ...                      ...
# 15742     78300                   26.6                     29.6
# 15743     82990                   26.6                     29.6
# 15744     82990                   22.3                     23.8
# 15745     70100                   25.0                     21.0
# 15746     10110                   20.0                      4.0
#
#        DiffMeanBonusPercent  DiffMedianBonusPercent  MaleBonusPercent  \
# 0                  18.40139                   15.55               0.0
# 1                  23.70000                  -75.20              22.2
# 2                  11.30000                   10.90              67.0
# 3                 -10.00000                   69.00              46.0
# 4                   0.00000                    0.00               0.0
# ...                     ...                     ...               ...
# 15742              56.90000                   53.20              95.0
# 15743              56.90000                   53.20              95.0
# 15744              51.60000                   50.60              95.0
# 15745              48.00000                   56.00              58.0
# 15746              86.00000                   15.00              46.0
#
#        FemaleBonusPercent  MaleLowerQuartile  FemaleLowerQuartile  \
# 0                     0.0               32.4                 67.6
# 1                    82.0               31.6                 68.4
# 2                    52.0               41.0                 59.0
# 3                    74.0                0.0                100.0
# 4                     0.0               38.1                 61.9
# ...                   ...                ...                  ...
# 15742                94.0               36.9                 63.1
# 15743                94.0               36.9                 63.1
# 15744                96.0               37.9                 62.1
# 15745                84.0               41.0                 59.0
# 15746                47.0               56.0                 44.0
#
#        MaleLowerMiddleQuartile  FemaleLowerMiddleQuartile  \
# 0                         38.2                       61.8
# 1                         12.7                       87.3
# 2                         45.0                       55.0
# 3                          2.0                       98.0
# 4                         43.6                       56.4
# ...                        ...                        ...
# 15742                     38.8                       61.2
# 15743                     38.8                       61.2
# 15744                     61.8                       38.2
# 15745                     62.0                       38.0
# 15746                     62.0                       38.0
#
#        MaleUpperMiddleQuartile  FemaleUpperMiddleQuartile  MaleTopQuartile  \
# 0                         44.9                       55.1             53.3
# 1                         11.6                       88.4             20.3
# 2                         50.0                       50.0             56.0
# 3                         17.0                       83.0             25.0
# 4                         48.4                       51.6             61.3
# ...                        ...                        ...              ...
# 15742                     54.4                       45.6             70.9
# 15743                     54.4                       45.6             70.9
# 15744                     71.0                       29.0             70.2
# 15745                     72.0                       28.0             80.0
# 15746                     62.0                       38.0             71.0
#
#        FemaleTopQuartile  EmployerSize  SIC Code  \
# 0                   46.7             3   85310.0
# 1                   79.7             2   47730.0
# 2                   44.0             0   61900.0
# 3                   75.0             2   78300.0
# 4                   38.7             2   85200.0
# ...                  ...           ...       ...
# 15742               29.1             0   78300.0
# 15743               29.1             0   82990.0
# 15744               29.8             0   82990.0
# 15745               20.0             2   70100.0
# 15746               29.0             3   10110.0
#
#                                              Description
# 0                            General secondary education
# 1               Dispensing chemist in specialised stores
# 2                    Other telecommunications activities
# 3      Human resources provision and management of hu...
# 4                                      Primary education
# ...                                                  ...
# 15742  Human resources provision and management of hu...
# 15743   Other business support service activities n.e.c.
# 15744   Other business support service activities n.e.c.
# 15745                         Activities of head offices
# 15746                  Processing and preserving of meat
#
# [13913 rows x 18 columns]

# %% [markdown]
# get percentage of women at each quartile as a factor of total women employees

# %%
new_data['FemalePerc']= 0.25 * (new_data.FemaleLowerQuartile + new_data.FemaleLowerMiddleQuartile +
                          new_data.FemaleUpperMiddleQuartile + new_data.FemaleTopQuartile)

# %%
new_data['MalePerc'] = 100 - new_data['FemalePerc']

# %%
# new_data['MalePercTest']= 0.25 * (new_data.MaleLowerQuartile + new_data.MaleLowerMiddleQuartile +
#                           new_data.MaleUpperMiddleQuartile + new_data.MaleTopQuartile)

# %%
new_data.head()
# Out:
#    SicCodes  DiffMeanHourlyPercent  DiffMedianHourlyPercent  \
# 0     85310                   19.6                     32.5
# 1     47730                    7.7                     -4.2
# 2     61900                    7.7                     12.7
# 3     78300                   30.0                     29.0
# 4     85200                   13.4                     12.7
#
#    DiffMeanBonusPercent  DiffMedianBonusPercent  MaleBonusPercent  \
# 0              18.40139                   15.55               0.0
# 1              23.70000                  -75.20              22.2
# 2              11.30000                   10.90              67.0
# 3             -10.00000                   69.00              46.0
# 4               0.00000                    0.00               0.0
#
#    FemaleBonusPercent  MaleLowerQuartile  FemaleLowerQuartile  \
# 0                 0.0               32.4                 67.6
# 1                82.0               31.6                 68.4
# 2                52.0               41.0                 59.0
# 3                74.0                0.0                100.0
# 4                 0.0               38.1                 61.9
#
#    MaleLowerMiddleQuartile  FemaleLowerMiddleQuartile  \
# 0                     38.2                       61.8
# 1                     12.7                       87.3
# 2                     45.0                       55.0
# 3                      2.0                       98.0
# 4                     43.6                       56.4
#
#    MaleUpperMiddleQuartile  FemaleUpperMiddleQuartile  MaleTopQuartile  \
# 0                     44.9                       55.1             53.3
# 1                     11.6                       88.4             20.3
# 2                     50.0                       50.0             56.0
# 3                     17.0                       83.0             25.0
# 4                     48.4                       51.6             61.3
#
#    FemaleTopQuartile  EmployerSize  SIC Code  \
# 0               46.7             3   85310.0
# 1               79.7             2   47730.0
# 2               44.0             0   61900.0
# 3               75.0             2   78300.0
# 4               38.7             2   85200.0
#
#                                          Description  FemalePerc  MalePerc
# 0                        General secondary education       57.80     42.20
# 1           Dispensing chemist in specialised stores       80.95     19.05
# 2                Other telecommunications activities       52.00     48.00
# 3  Human resources provision and management of hu...       89.00     11.00
# 4                                  Primary education       52.15     47.85

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.svm import SVR
from math import sqrt
# https://www.kaggle.com/learn/intro-to-machine-learning

# %%
def svr(train_X, val_X, train_y, val_y):
    
    model =SVR(gamma=0.00009,C=10, epsilon=0.2)
    
    # Fit model
    model.fit(train_X, train_y)
    
    # get predicted prices on validation data
    val_predictions = model.predict(val_X)
    print("SVM mean absolute error:",mean_absolute_error(val_y, val_predictions))
    print("SVM root mean squared error:",sqrt(mean_squared_error(val_y, val_predictions)))
    print("SVM R^2 score: ",model.score(val_X, val_y))
    return model

# %%
def decision_tree(train_X, val_X, train_y, val_y):
    # Define model. Specify a number for random_state to ensure same results each run
    model = DecisionTreeRegressor(random_state=1, max_depth=10, min_samples_split=10)

    # Fit model
    model.fit(train_X, train_y)

    # get predicted prices on validation data
    val_predictions = model.predict(val_X)
    print("Decision tree mean absolute error:",mean_absolute_error(val_y, val_predictions))
    print("Decision tree root mean squared error:",sqrt(mean_squared_error(val_y, val_predictions)))
    #print("Decision tree AIC:",aic(val_y, val_predictions, len(val_X.columns)))
    print("Decision tree R^2 score: ",model.score(val_X, val_y))
    return model

# %%
def random_forest(train_X, val_X, train_y, val_y):
    forest_model = RandomForestRegressor(random_state=1)
    forest_model.fit(train_X, train_y)
    new_preds = forest_model.predict(val_X)
    print("Random forest mae:",mean_absolute_error(val_y, new_preds))
    print("Random forest rmse:",sqrt(mean_squared_error(val_y, new_preds)))
    #print("Random forest AIC: ", aic(val_y, new_preds, len(val_X.columns) ))
    print("Random forest R^2 score:", forest_model.score(val_X, val_y)) #coefficient of determination R^2 of the prediction
    #accuracy(val_y,new_preds)
    return forest_model

# %%
#https://en.wikipedia.org/wiki/Akaike_information_criterion
#https://www.reddit.com/r/statistics/comments/5h2rbw/does_python_have_a_package_for_aicbic/
def aic(y, pred, k):
    error = y - pred
    sse = sum(error ** 2)
    aic = 2 * k - 2 * np.log(sse)
    return aic

# %%
def feature_imp(model, train_X):
    feature_importances = pd.DataFrame(model.feature_importances_,
    index = train_X.columns,
    columns=['importance']).sort_values('importance', ascending=False)
    sns.barplot(data=feature_importances.reset_index(),x='importance',y='index',orient='h')

# %%
def adaboost(train_X, val_X, train_y, val_y):
    adaboost_model = AdaBoostRegressor(random_state=1)
    adaboost_model.fit(train_X, train_y)
    val_predictions = adaboost_model.predict(val_X)
    print("Adaboost mae:",mean_absolute_error(val_y, val_predictions))
    print("Adaboost rmse:",sqrt(mean_squared_error(val_y, val_predictions)))
   # print("Adaboost aic:",aic(val_y, val_predictions, len(val_X.columns)))
    print("Adaboost R^2 score", adaboost_model.score(val_X, val_y))
    return adaboost_model

# %%
def gradboost(train_X, val_X, train_y, val_y):
    grad_model = GradientBoostingRegressor(random_state=1)
    grad_model.fit(train_X, train_y)
    val_predictions = grad_model.predict(val_X)
    print("Gradient Boosting mae:",mean_absolute_error(val_y, val_predictions))
    print("Gradient Boosting rmse:",sqrt(mean_squared_error(val_y, val_predictions)))
    #print("Gradient Boosting aic:",aic(val_y, val_predictions, len(val_X.columns)))
    print("Gradient Boosting R^2 score", grad_model.score(val_X, val_y))
    return grad_model

# %%
def accuracy(target, pred): #bad idea for this since target may be zero
    # Calculate mean absolute percentage error (MAPE)
    errors = abs(target - pred)
    mape = 100 * (errors / target)
    # Calculate and display accuracy
    accuracy = 100 - np.mean(mape)
    print('Accuracy:', round(accuracy, 2), '%.')

# %%
#predict mean hourly rate
y = new_data.DiffMeanHourlyPercent
features = ['DiffMeanBonusPercent','DiffMedianBonusPercent','MaleBonusPercent',
       'FemaleBonusPercent','MaleLowerQuartile','FemaleLowerQuartile',
       'MaleLowerMiddleQuartile', 'FemaleLowerMiddleQuartile',
       'MaleUpperMiddleQuartile', 'FemaleUpperMiddleQuartile',
       'MaleTopQuartile', 'FemaleTopQuartile','EmployerSize','SicCodes']
X = new_data[features]
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 1) #test_size=0.25
svr_model = svr(train_X, val_X, train_y, val_y)
decision_tree_model = decision_tree(train_X, val_X, train_y, val_y)
forest_model = random_forest(train_X, val_X, train_y, val_y)
adaboost_model = adaboost(train_X, val_X, train_y, val_y)
gradboost_model = gradboost(train_X, val_X, train_y, val_y)
#adaboost_model.feature_importances_
# Out:
# SVM mean absolute error: 6.271440731806938
# SVM root mean squared error: 9.579959219776782
# SVM R^2 score:  0.5213225927443997
# Decision tree mean absolute error: 6.386809023942237
# Decision tree root mean squared error: 9.487631464599636
# Decision tree R^2 score:  0.5305047284330093
# Random forest mae: 4.405090170180341
# Random forest rmse: 7.419843736694335
# Random forest R^2 score: 0.7128524419048714
# Adaboost mae: 8.089903587280705
# Adaboost rmse: 10.877226048358501
# Adaboost R^2 score 0.3829051565610359
# Gradient Boosting mae: 5.663653320332785
# Gradient Boosting rmse: 8.501826216128324
# Gradient Boosting R^2 score 0.6230011233763961

# %%
def correlatePredictions(model, val_X, val_y, name):
    preds = model.predict(val_X)
    fig, ax = plt.subplots(figsize=(7, 5))
    sns.scatterplot(preds, val_y)
    # ax.plot(val_X.index, preds,label='Predicted value')
    #ax.legend()
    ax.set(xlabel='Predictions', ylabel='Actual pay gap',
           title=name)
    plt.show()

# %%
correlatePredictions(decision_tree_model,val_X,val_y,"Decision Tree")
feature_imp(decision_tree_model,train_X)

# %%
correlatePredictions(forest_model,val_X,val_y,"Random Forest")
feature_imp(forest_model,train_X)

# %%
correlatePredictions(adaboost_model,val_X,val_y,"Adaboost Model")
feature_imp(adaboost_model,train_X)

# %%
correlatePredictions(gradboost_model,val_X,val_y,"Gradient Boost Model")
feature_imp(gradboost_model,train_X)

# %%
correlatePredictions(svr_model,val_X,val_y,"SVM")

# %%
#predict median hourly rate
#https://stats.stackexchange.com/questions/131267/how-to-interpret-error-measures
y = new_data.DiffMedianHourlyPercent
features = ['DiffMedianBonusPercent','DiffMeanBonusPercent','MaleBonusPercent',
       'FemaleBonusPercent','MaleLowerQuartile','FemaleLowerQuartile',
       'MaleLowerMiddleQuartile', 'FemaleLowerMiddleQuartile',
       'MaleUpperMiddleQuartile', 'FemaleUpperMiddleQuartile',
       'MaleTopQuartile', 'FemaleTopQuartile','EmployerSize','SicCodes']
X = new_data[features]
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 1)
median_decision_tree_model = decision_tree(train_X, val_X, train_y, val_y)
median_forest_model = random_forest(train_X, val_X, train_y, val_y)
median_adaboost_model = adaboost(train_X, val_X, train_y, val_y)
median_gradboost_model = gradboost(train_X, val_X, train_y, val_y)
median_svr_model = svr(train_X, val_X, train_y, val_y)
# Out:
# Decision tree mean absolute error: 7.282629046420693
# Decision tree root mean squared error: 10.58474402024897
# Decision tree R^2 score:  0.561295083044715
# Random forest mae: 5.068757937515876
# Random forest rmse: 8.247169737965708
# Random forest R^2 score: 0.7336690434706868
# Adaboost mae: 10.957402323957178
# Adaboost rmse: 14.12654066969233
# Adaboost R^2 score 0.2185819638985932
# Gradient Boosting mae: 6.7062775888594235
# Gradient Boosting rmse: 9.702959238005564
# Gradient Boosting R^2 score 0.6313449421833284
# SVM mean absolute error: 7.201584558786767
# SVM root mean squared error: 10.851767112168552
# SVM R^2 score:  0.5388813235768001

# %%
# from sklearn import tree
# import graphviz

# tree_graph = tree.export_graphviz(median_decision_tree_model, out_file=None, feature_names=features)
# graphviz.Source(tree_graph)

# %%
correlatePredictions(median_decision_tree_model,val_X,val_y,"Decision tree")
feature_imp(median_decision_tree_model,train_X)

# %%
correlatePredictions(median_forest_model,val_X,val_y,"Random Forest")
feature_imp(median_forest_model,train_X)

# %%
correlatePredictions(median_adaboost_model,val_X,val_y,"AdaBoost Model")
feature_imp(median_adaboost_model,train_X)

# %%
correlatePredictions(median_gradboost_model,val_X,val_y,"Gradient Boost Model")

feature_imp(median_gradboost_model,train_X)

# %%
correlatePredictions(median_svr_model,val_X,val_y,"SVM")

# %%
trial_data = data.copy()

# %%
new_data.groupby('EmployerSize').count()['DiffMeanHourlyPercent'].sort_values(ascending=False)
# Out:
# EmployerSize
# 2    7017
# 3    3814
# 0    3514
# 4     808
# 5     484
# 1      99
# 6      11
# Name: DiffMeanHourlyPercent, dtype: int64

# %%
new_data.groupby('SicCodes').count()['DiffMeanHourlyPercent'].sort_values(ascending=False)
# Out:
# SicCodes
# 1        1834
# 85310     654
# 82990     578
# 85200     438
# 84110     383
#          ...
# 24410       1
# 24520       1
# 25290       1
# 74201       1
# 46360       1
# Name: DiffMeanHourlyPercent, Length: 621, dtype: int64

# %% [markdown]
# Imbalance in class...This needs work

# %% [markdown]
# ## Permutation importance
#
# https://www.kaggle.com/dansbecker/permutation-importance

# %%
import eli5
from eli5.sklearn import PermutationImportance
# Out:
# Using TensorFlow backend.

# %%
perm = PermutationImportance(median_forest_model, random_state=1).fit(val_X, val_y)
eli5.show_weights(perm, feature_names = val_X.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.3927
#
#                     &plusmn; 0.0180
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MaleLowerQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.72%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.3727
#
#                     &plusmn; 0.0086
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 FemaleLowerQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.79%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.3708
#
#                     &plusmn; 0.0259
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MaleTopQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 81.71%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.3456
#
#                     &plusmn; 0.0053
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 FemaleTopQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.53%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0784
#
#                     &plusmn; 0.0064
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 SicCodes
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.71%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0752
#
#                     &plusmn; 0.0081
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MaleLowerMiddleQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.81%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0736
#
#                     &plusmn; 0.0074
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DiffMedianBonusPercent
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.79%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0575
#
#                     &plusmn; 0.0041
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 FemaleLowerMiddleQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.16%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0517
#
#                     &plusmn; 0.0033
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MaleUpperMiddleQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.53%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0461
#
#                     &plusmn; 0.0052
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 FemaleUpperMiddleQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.15%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0373
#
#                     &plusmn; 0.0095
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MaleBonusPercent
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.24%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0232
#
#                     &plusmn; 0.0014
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 FemaleBonusPercent
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.38%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0215
#
#                     &plusmn; 0.0049
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DiffMeanBonusPercent
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.96%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0058
#
#                     &plusmn; 0.0042
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 EmployerSize
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
perm = PermutationImportance(median_gradboost_model, random_state=1).fit(val_X, val_y)
eli5.show_weights(perm, feature_names = val_X.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2474
#
#                     &plusmn; 0.0064
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 FemaleTopQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.66%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2358
#
#                     &plusmn; 0.0114
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MaleLowerQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 81.16%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2271
#
#                     &plusmn; 0.0188
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 FemaleLowerQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.59%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1865
#
#                     &plusmn; 0.0129
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MaleTopQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.88%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0935
#
#                     &plusmn; 0.0063
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 SicCodes
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.24%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0640
#
#                     &plusmn; 0.0054
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MaleLowerMiddleQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.76%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0579
#
#                     &plusmn; 0.0058
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 FemaleLowerMiddleQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.20%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0530
#
#                     &plusmn; 0.0053
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 FemaleUpperMiddleQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.35%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0308
#
#                     &plusmn; 0.0026
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MaleUpperMiddleQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.59%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0198
#
#                     &plusmn; 0.0023
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DiffMedianBonusPercent
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.23%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0147
#
#                     &plusmn; 0.0018
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MaleBonusPercent
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.67%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0052
#
#                     &plusmn; 0.0016
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 FemaleBonusPercent
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.04%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0032
#
#                     &plusmn; 0.0017
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DiffMeanBonusPercent
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.46%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0014
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 EmployerSize
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %%
perm = PermutationImportance(median_svr_model, random_state=1).fit(val_X, val_y)
eli5.show_weights(perm, feature_names = val_X.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.4078
#
#                     &plusmn; 0.0226
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 SicCodes
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.11%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2176
#
#                     &plusmn; 0.0137
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 FemaleLowerQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.17%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2163
#
#                     &plusmn; 0.0151
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MaleLowerQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.65%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2048
#
#                     &plusmn; 0.0226
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 FemaleLowerMiddleQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.19%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1922
#
#                     &plusmn; 0.0075
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MaleLowerMiddleQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.73%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1360
#
#                     &plusmn; 0.0077
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 FemaleTopQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.01%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1301
#
#                     &plusmn; 0.0116
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MaleTopQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.33%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0673
#
#                     &plusmn; 0.0052
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 FemaleUpperMiddleQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0637
#
#                     &plusmn; 0.0073
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MaleUpperMiddleQuartile
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.65%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0619
#
#                     &plusmn; 0.0092
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 MaleBonusPercent
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.65%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0462
#
#                     &plusmn; 0.0019
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DiffMedianBonusPercent
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.46%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0343
#
#                     &plusmn; 0.0089
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 DiffMeanBonusPercent
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.69%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0312
#
#                     &plusmn; 0.0048
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 FemaleBonusPercent
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0001
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 EmployerSize
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %% [markdown]
# ## Partial dependence plot

# %%
from pdpbox import pdp, get_dataset, info_plots

# %%
def pdpFunction(model,data,features,feature_to_plot):
    pdp_score = pdp.pdp_isolate(model=model, dataset=data, model_features=features,
                                feature=feature_to_plot)
    pdp.pdp_plot(pdp_score, feature_to_plot)
    plt.show()
    #pdp.plt.savefig('Visualizations/'+feature_to_plot+'.png')

# %%
pdpFunction(median_forest_model,val_X,features,'FemaleLowerQuartile')

# %%
pdpFunction(median_forest_model,val_X,features,'FemaleTopQuartile')

# %%
pdpFunction(median_forest_model,val_X,features,'EmployerSize')

# %%
pdpFunction(median_forest_model,val_X,features,'SicCodes')

# %%
pdpFunction(median_gradboost_model,val_X,features,'SicCodes')

# %%
pdpFunction(median_svr_model,val_X,features,'SicCodes')

# %%
pdpFunction(median_svr_model,val_X,features,'FemaleLowerQuartile')

# %%
# https://github.com/slundberg/shap
# this takes time
import shap

# Create object that can calculate shap values
explainer = shap.TreeExplainer(median_forest_model)

# calculate shap values. This is what we will plot.
# Calculate shap_values for all of val_X rather than a single row, to have more data for plot.
shap_values = explainer.shap_values(val_X)


shap.summary_plot(shap_values, val_X)

# %%
# Create object that can calculate shap values
explainer = shap.TreeExplainer(median_gradboost_model)

# calculate shap values. This is what we will plot.
# Calculate shap_values for all of val_X rather than a single row, to have more data for plot.
shap_values = explainer.shap_values(val_X)


shap.summary_plot(shap_values, val_X)
